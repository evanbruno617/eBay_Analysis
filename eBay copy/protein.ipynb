# %%
import pandas as pd

# %%
data_df = pd.read_csv('protein.csv')
data_df
# Out:
#       Unnamed: 0                                            Listing  \
# 0              0  , preview full size imageOptimum Nutrition Ser...
# 1              1  , preview full size imageLevels Grass Fed 100%...
# 2              2  , preview full size imageVPX Delicious Syngex ...
# 3              3  , preview full size imageColossal Labs Nutriti...
# 4              4  , preview full size imageBarebells Protein Bar...
# ...          ...                                                ...
# 9995          45  , preview full size imageMuscle Milk Pro Serie...
# 9996          46  , preview full size imageWhey Protein Powder M...
# 9997          47  , preview full size imageAscent Native Fuel Wh...
# 9998          48  , preview full size imageLOT OF (2) Vega Organ...
# 9999          49  , preview full size imageOptimum Nutrition Ser...
#
#                               Actions      Avg Sold Price  \
# 0     EditSell SimilarExclude listing   $46.26Fixed price
# 1     EditSell SimilarExclude listing   $54.99Fixed price
# 2     EditSell SimilarExclude listing   $37.99Fixed price
# 3     EditSell SimilarExclude listing  $107.44Fixed price
# 4     EditSell SimilarExclude listing   $23.09Fixed price
# ...                               ...                 ...
# 9995              EditExclude listing   $65.48Fixed price
# 9996  EditSell SimilarExclude listing   $21.79Fixed price
# 9997              EditExclude listing   $24.99Fixed price
# 9998              EditExclude listing   $39.99Fixed price
# 9999              EditExclude listing   $39.74Fixed price
#
#                  Avg Shipping Total Sold    Item_Sale Bids Date Last Sold
# 0     $0.00100% Free shipping         11      $508.89    –   Mar 19, 2024
# 1       $4.000% Free shipping          1       $54.99    –   Mar 19, 2024
# 2      $24.990% Free shipping          1       $37.99    –   Mar 19, 2024
# 3     $0.00100% Free shipping      1,233  $132,472.78    –   Mar 19, 2024
# 4     $0.00100% Free shipping          8      $184.71    –   Mar 19, 2024
# ...                       ...        ...          ...  ...            ...
# 9995  $0.00100% Free shipping          1       $65.48    –   Oct 19, 2023
# 9996  $0.00100% Free shipping          4       $87.16    –   Oct 19, 2023
# 9997  $0.00100% Free shipping          1       $24.99    –   Oct 19, 2023
# 9998  $0.00100% Free shipping          1       $39.99    –   Oct 19, 2023
# 9999    $4.000% Free shipping          1       $39.74    –   Oct 19, 2023
#
# [10000 rows x 9 columns]

# %%
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag

# Download NLTK resources (only need to do this once)
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

# Function to extract keywords
def extract_keywords(text):
    tokens = word_tokenize(text)
    tagged_tokens = pos_tag(tokens)
    keywords = [word for word, pos in tagged_tokens if pos in ['NN', 'NNS', 'NNP', 'JJ']]
    return keywords
# Out:
# [nltk_data] Downloading package punkt to /Users/evanbruno/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/evanbruno/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
# Function to extract and format the first part of the string
def extract_and_format(value):
    parts = value.split('%')[0].split('$')[1]
    first_part = parts.strip()
    formatted_value = '{:.2f}'.format(float(first_part[1:]))
    return formatted_value
# Remove commas from all values in the DataFrame
data_df = data_df.replace(',', '', regex=True)
# 
data_df['Avg_Sold_Price'] = data_df['Avg Sold Price'].apply(lambda x: x.split('$')[1].split('F')[0].split('A')[0]).astype(float)

# 
data_df['Total_Sales'] = data_df['Item_Sale'].apply(lambda x: x.split('$')[1]).astype(float)

data_df['Total_Sold'] = data_df['Total Sold'].astype(float)

# Convert string to datetime
data_df['Date'] = pd.to_datetime(data_df['Date Last Sold'])

# Apply the function to the column
data_df['Shipping'] = data_df['Avg Shipping'].apply(lambda x: extract_and_format(x)).astype(float)

data_df.drop(columns=['Unnamed: 0', 'Actions', 'Avg Sold Price', 'Bids', 'Date Last Sold', 'Avg Shipping', 'Item_Sale', 'Total Sold'], inplace=True)

data_df['Listing'] = data_df['Listing'].apply(lambda x: x.split('image')[-1])

# Apply the function to both listing titles and descriptions
data_df['Title_Keywords'] = data_df['Listing'].apply(extract_keywords)

data_df
# Out:
#                                                 Listing  Avg_Sold_Price  \
# 0     Optimum Nutrition Serious Mass Weight Gainer P...           46.26
# 1     Levels Grass Fed 100% Whey Protein No Hormones...           54.99
# 2     VPX Delicious Syngex 5 Lbs Serious Chocolate 5...           37.99
# 3     Colossal Labs Nutritional Whey Protein Powder ...          107.44
# 4     Barebells Protein Bar Cookies & Cream 12 bars....           23.09
# ...                                                 ...             ...
# 9995  Muscle Milk Pro Series Protein Powder Suppleme...           65.48
# 9996  Whey Protein Powder Muscletech Grass-Fed Tripl...           21.79
# 9997  Ascent Native Fuel Whey Protein Powder 32oz Ba...           24.99
# 9998  LOT OF (2) Vega Organic Protein and Greens Pow...           39.99
# 9999  Optimum Nutrition Serious Mass Protein - Straw...           39.74
#
#       Total_Sales  Total_Sold       Date  Shipping  \
# 0          508.89        11.0 2024-03-19      0.00
# 1           54.99         1.0 2024-03-19      0.00
# 2           37.99         1.0 2024-03-19      4.99
# 3       132472.78      1233.0 2024-03-19      0.00
# 4          184.71         8.0 2024-03-19      0.00
# ...           ...         ...        ...       ...
# 9995        65.48         1.0 2023-10-19      0.00
# 9996        87.16         4.0 2023-10-19      0.00
# 9997        24.99         1.0 2023-10-19      0.00
# 9998        39.99         1.0 2023-10-19      0.00
# 9999        39.74         1.0 2023-10-19      0.00
#
#                                          Title_Keywords
# 0     [Optimum, Nutrition, Serious, Mass, Weight, Ga...
# 1     [Levels, Grass, Fed, %, Whey, Protein, No, Hor...
# 2     [VPX, Delicious, Syngex, Lbs, Serious, Chocola...
# 3     [Colossal, Labs, Nutritional, Whey, Protein, P...
# 4     [Barebells, Protein, Bar, Cookies, Cream, bars...
# ...                                                 ...
# 9995  [Muscle, Milk, Pro, Series, Protein, Powder, S...
# 9996  [Whey, Protein, Powder, Muscletech, Grass-Fed,...
# 9997  [Ascent, Native, Fuel, Whey, Protein, Powder, ...
# 9998  [LOT, OF, Vega, Organic, Protein, Greens, Powd...
# 9999  [Optimum, Nutrition, Serious, Mass, Protein, S...
#
# [10000 rows x 7 columns]

# %% [markdown]
# # Popular Whole df

# %%
filtered_df= data_df.loc[data_df['Avg_Sold_Price'] > 10]
filtered_df
# Out:
#                                                 Listing  Avg_Sold_Price  \
# 0     Optimum Nutrition Serious Mass Weight Gainer P...           46.26
# 1     Levels Grass Fed 100% Whey Protein No Hormones...           54.99
# 2     VPX Delicious Syngex 5 Lbs Serious Chocolate 5...           37.99
# 3     Colossal Labs Nutritional Whey Protein Powder ...          107.44
# 4     Barebells Protein Bar Cookies & Cream 12 bars....           23.09
# ...                                                 ...             ...
# 9995  Muscle Milk Pro Series Protein Powder Suppleme...           65.48
# 9996  Whey Protein Powder Muscletech Grass-Fed Tripl...           21.79
# 9997  Ascent Native Fuel Whey Protein Powder 32oz Ba...           24.99
# 9998  LOT OF (2) Vega Organic Protein and Greens Pow...           39.99
# 9999  Optimum Nutrition Serious Mass Protein - Straw...           39.74
#
#       Total_Sales  Total_Sold       Date  Shipping  \
# 0          508.89        11.0 2024-03-19      0.00
# 1           54.99         1.0 2024-03-19      0.00
# 2           37.99         1.0 2024-03-19      4.99
# 3       132472.78      1233.0 2024-03-19      0.00
# 4          184.71         8.0 2024-03-19      0.00
# ...           ...         ...        ...       ...
# 9995        65.48         1.0 2023-10-19      0.00
# 9996        87.16         4.0 2023-10-19      0.00
# 9997        24.99         1.0 2023-10-19      0.00
# 9998        39.99         1.0 2023-10-19      0.00
# 9999        39.74         1.0 2023-10-19      0.00
#
#                                          Title_Keywords
# 0     [Optimum, Nutrition, Serious, Mass, Weight, Ga...
# 1     [Levels, Grass, Fed, %, Whey, Protein, No, Hor...
# 2     [VPX, Delicious, Syngex, Lbs, Serious, Chocola...
# 3     [Colossal, Labs, Nutritional, Whey, Protein, P...
# 4     [Barebells, Protein, Bar, Cookies, Cream, bars...
# ...                                                 ...
# 9995  [Muscle, Milk, Pro, Series, Protein, Powder, S...
# 9996  [Whey, Protein, Powder, Muscletech, Grass-Fed,...
# 9997  [Ascent, Native, Fuel, Whey, Protein, Powder, ...
# 9998  [LOT, OF, Vega, Organic, Protein, Greens, Powd...
# 9999  [Optimum, Nutrition, Serious, Mass, Protein, S...
#
# [9707 rows x 7 columns]

# %%
from collections import Counter

# %%
def extract_phrases(title):
    tokens = title.split()  # Tokenize the title
    phrases = []
    for i in range(len(tokens)):
        for j in range(i + 1, min(i + 6, len(tokens) + 1)):  # Generate combinations of 2 to 5 words
            phrase = ' '.join(tokens[i:j])
            if len(phrase.split()) >= 2 and len(phrase.split()) <= 5:  # Check if phrase length is between 2 and 5
                phrases.append(phrase)
    return phrases

# Apply the function to the Titles column
phrases = filtered_df['Listing'].apply(extract_phrases).sum()

# Count the occurrences of each phrase
phrase_counts = Counter(phrases)

# Find the most common phrases
most_common_phrases = phrase_counts.most_common()

most_common_phrases_df = pd.DataFrame(most_common_phrases, columns=['Name', 'Count'])
most_common_phrases_df.head(25)
# Out:
#                                  Name  Count
# 0                      Protein Powder   8171
# 1                        Whey Protein   6144
# 2                 Whey Protein Powder   2840
# 3                           100% Whey   2822
# 4                       Gold Standard   2264
# 5                   100% Whey Protein   2041
# 6                      Nutrition Gold   1911
# 7             Nutrition Gold Standard   1825
# 8                       Standard 100%   1498
# 9                  Gold Standard 100%   1426
# 10                 Standard 100% Whey   1404
# 11                    Protein Isolate   1391
# 12            Gold Standard 100% Whey   1350
# 13                  Optimum Nutrition   1311
# 14       Nutrition Gold Standard 100%   1252
# 15               Whey Protein Isolate   1219
# 16  Nutrition Gold Standard 100% Whey   1198
# 17           100% Whey Protein Powder   1163
# 18         Standard 100% Whey Protein   1039
# 19    Gold Standard 100% Whey Protein   1013
# 20             Optimum Nutrition Gold   1012
# 21                     Powder Vanilla    970
# 22    Optimum Nutrition Gold Standard    964
# 23             Protein Powder Vanilla    921
# 24                           Powder -    858

# %%
type_product = most_common_phrases_df['Name'].head(100).tolist()

# %%
dict_sales = {'Phrase': [], 'Avg_Sold_Price_mean': [], 'Avg_Sold_Price_25': [], 'Avg_Sold_Price_75': [], 'Total_Sold': [], 'Ship_Cost': []}

# %%
dict_sales = {'Phrase': [], 'Avg_Sold_Price_mean': [], 'Avg_Sold_Price_25': [], 'Avg_Sold_Price_75': [], 'Total_Sold': [], 'Ship_Cost': [], 'Count_Unique': []}


for phrase in type_product:
    # Filter rows where 'filtered_df' or 'Vitamin' is in the list
    temp_df = filtered_df[filtered_df['Listing'].apply(lambda x: phrase in x)]

    mean = temp_df.describe()['Avg_Sold_Price'].tolist()[1]

    percent_25 = temp_df.describe()['Avg_Sold_Price'].tolist()[4]

    percent_75 = temp_df.describe()['Avg_Sold_Price'].tolist()[6]

    total = temp_df['Total_Sold'].sum()

    ship = temp_df.describe()['Shipping'].tolist()[5]
    
    count =  temp_df.describe()['Total_Sold'].tolist()[0]
    
    dict_sales['Phrase'].append(phrase)
    dict_sales['Avg_Sold_Price_mean'].append(mean)
    dict_sales['Avg_Sold_Price_25'].append(percent_25)
    dict_sales['Avg_Sold_Price_75'].append(percent_75)
    dict_sales['Total_Sold'].append(total)
    dict_sales['Ship_Cost'].append(ship)
    dict_sales['Count_Unique'].append(count)
    
stats_df = pd.DataFrame.from_dict(dict_sales)

stats_df['Ratio_Sold_Count'] = stats_df['Total_Sold'] / stats_df['Count_Unique']

# %%
stats_df.sort_values(by='Avg_Sold_Price_mean', ascending=False).head(10)
# Out:
#                                   Phrase  Avg_Sold_Price_mean  \
# 71     Gold Standard Whey Protein Powder            59.240714
# 70          Standard Whey Protein Powder            59.240714
# 61  Nutrition Gold Standard Whey Protein            58.087836
# 57          Nutrition Gold Standard Whey            57.525440
# 56            Gold Standard Whey Protein            56.825376
# 55                 Standard Whey Protein            56.825376
# 92                           Chocolate 5            55.973858
# 87                        Milk Chocolate            54.391559
# 44                         Standard Whey            53.892646
# 49                    Gold Standard Whey            53.892646
#
#     Avg_Sold_Price_25  Avg_Sold_Price_75  Total_Sold  Ship_Cost  Count_Unique  \
# 71            39.2475            68.9175       655.0        0.0         154.0
# 70            39.2475            68.9175       655.0        0.0         154.0
# 61            36.9750            68.8350       587.0        0.0         171.0
# 57            37.9625            67.8050       607.0        0.0         182.0
# 56            35.9925            65.8750       706.0        0.0         186.0
# 55            35.9925            65.8750       706.0        0.0         186.0
# 92            43.7200            68.9900      1006.0        0.0         197.0
# 87            36.0000            64.9900       845.0        0.0         186.0
# 44            35.0000            64.9900      2176.0        0.0         223.0
# 49            35.0000            64.9900      2176.0        0.0         223.0
#
#     Ratio_Sold_Count
# 71          4.253247
# 70          4.253247
# 61          3.432749
# 57          3.335165
# 56          3.795699
# 55          3.795699
# 92          5.106599
# 87          4.543011
# 44          9.757848
# 49          9.757848

# %%
stats_df.sort_values(by='Total_Sold', ascending=False).head(10)
# Out:
#                     Phrase  Avg_Sold_Price_mean  Avg_Sold_Price_25  \
# 0           Protein Powder            40.066402            24.1600
# 1             Whey Protein            44.695108            27.9575
# 2      Whey Protein Powder            42.877960            25.0000
# 11         Protein Isolate            49.432458            32.9650
# 3                100% Whey            46.470076            28.9900
# 15    Whey Protein Isolate            49.480668            33.9800
# 13       Optimum Nutrition            52.086505            35.4200
# 4            Gold Standard            51.261417            34.4575
# 86  Nutricost Whey Protein            44.241339            38.6725
# 85          Nutricost Whey            44.241339            38.6725
#
#     Avg_Sold_Price_75  Total_Sold  Ship_Cost  Count_Unique  Ratio_Sold_Count
# 0              49.990     29744.0        0.0        4313.0          6.896360
# 1              55.000     27947.0        0.0        3150.0          8.872063
# 2              55.000     10951.0        0.0        1490.0          7.349664
# 11             55.000      8600.0        0.0         712.0         12.078652
# 3              59.645      7449.0        0.0        1444.0          5.158587
# 15             54.990      7098.0        0.0         644.0         11.021739
# 13             61.380      6248.0        0.0        1199.0          5.211009
# 4              60.000      5836.0        0.0        1186.0          4.920742
# 86             49.705      5355.0        0.0         254.0         21.082677
# 85             49.705      5355.0        0.0         254.0         21.082677

# %%
stats_df.sort_values(by='Ratio_Sold_Count', ascending=False).head(10)
# Out:
#                     Phrase  Avg_Sold_Price_mean  Avg_Sold_Price_25  \
# 86  Nutricost Whey Protein            44.241339            38.6725
# 85          Nutricost Whey            44.241339            38.6725
# 11         Protein Isolate            49.432458            32.9650
# 58             Mass Gainer            41.492640            28.3600
# 15    Whey Protein Isolate            49.480668            33.9800
# 50          Gainer Protein            47.572282            29.1250
# 68   Gainer Protein Powder            44.807692            28.5525
# 49      Gold Standard Whey            53.892646            35.0000
# 44           Standard Whey            53.892646            35.0000
# 1             Whey Protein            44.695108            27.9575
#
#     Avg_Sold_Price_75  Total_Sold  Ship_Cost  Count_Unique  Ratio_Sold_Count
# 86            49.7050      5355.0        0.0         254.0         21.082677
# 85            49.7050      5355.0        0.0         254.0         21.082677
# 11            55.0000      8600.0        0.0         712.0         12.078652
# 58            47.9800      2376.0        0.0         197.0         12.060914
# 15            54.9900      7098.0        0.0         644.0         11.021739
# 50            58.0350      2084.0        0.0         206.0         10.116505
# 68            50.8775      1782.0        0.0         182.0          9.791209
# 49            64.9900      2176.0        0.0         223.0          9.757848
# 44            64.9900      2176.0        0.0         223.0          9.757848
# 1             55.0000     27947.0        0.0        3150.0          8.872063
