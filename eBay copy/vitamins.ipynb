# %%
import pandas as pd

# %%
data_df = pd.read_csv('vitamins.csv')
data_df
# Out:
#       Unnamed: 0                                            Listing  \
# 0              0  , preview full size imageInnerzyme Vitamin K2 ...
# 1              1  , preview full size imageNeuroCare Natural Bra...
# 2              2  , preview full size imageSuper Beta Prostate U...
# 3              3  , preview full size imageGNC Probiotic Complex...
# 4              4  , preview full size image5-Pack Sight Care Vis...
# ...          ...                                                ...
# 1345          45  , preview full size imageReserveage Keratin Ha...
# 1346          46  , preview full size imageATHLETIC GREENS AG1 C...
# 1347          47  , preview full size imageKokando Slimming Prod...
# 1348          48  , preview full size imageNATURELO Raw Greens S...
# 1349          49  , preview full size imageStandard Process - Im...
#
#                               Actions     Avg Sold Price  \
# 0     EditSell SimilarExclude listing  $30.34Fixed price
# 1     EditSell SimilarExclude listing  $26.67Fixed price
# 2     EditSell SimilarExclude listing  $21.42Fixed price
# 3     EditSell SimilarExclude listing  $29.00Fixed price
# 4     EditSell SimilarExclude listing  $55.71Fixed price
# ...                               ...                ...
# 1345  EditSell SimilarExclude listing  $39.85Fixed price
# 1346  EditSell SimilarExclude listing  $75.99Fixed price
# 1347  EditSell SimilarExclude listing  $25.33Fixed price
# 1348  EditSell SimilarExclude listing  $39.00Fixed price
# 1349  EditSell SimilarExclude listing  $64.95Fixed price
#
#                  Avg Shipping Total Sold   Item_Sale Bids Date Last Sold
# 0     $0.00100% Free shipping          3      $91.03    –   Mar 19, 2024
# 1      $8.3080% Free shipping        982  $26,185.25    –   Mar 19, 2024
# 2     $0.00100% Free shipping         12     $256.98    –   Mar 19, 2024
# 3     $0.00100% Free shipping          1      $29.00    –   Mar 19, 2024
# 4     $0.00100% Free shipping        367  $20,444.31    –   Mar 19, 2024
# ...                       ...        ...         ...  ...            ...
# 1345  $0.00100% Free shipping          2      $79.70    –   Mar 18, 2024
# 1346    $6.330% Free shipping          2     $151.98    –   Mar 18, 2024
# 1347  $0.00100% Free shipping         55   $1,392.95    –   Mar 18, 2024
# 1348  $0.00100% Free shipping          1      $39.00    –   Mar 18, 2024
# 1349  $0.00100% Free shipping         44   $2,857.98    –   Mar 18, 2024
#
# [1350 rows x 9 columns]

# %%
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag

# Download NLTK resources (only need to do this once)
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

# Function to extract keywords
def extract_keywords(text):
    tokens = word_tokenize(text)
    tagged_tokens = pos_tag(tokens)
    keywords = [word for word, pos in tagged_tokens if pos in ['NN', 'NNS', 'NNP', 'JJ']]
    return keywords
# Out:
# [nltk_data] Downloading package punkt to /Users/evanbruno/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/evanbruno/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
# Function to extract and format the first part of the string
def extract_and_format(value):
    parts = value.split('%')[0].split('$')[1]
    first_part = parts.strip()
    formatted_value = '{:.2f}'.format(float(first_part[1:]))
    return formatted_value
# Remove commas from all values in the DataFrame
data_df = data_df.replace(',', '', regex=True)
# 
data_df['Avg_Sold_Price'] = data_df['Avg Sold Price'].apply(lambda x: x.split('$')[1].split('F')[0].split('A')[0]).astype(float)

# 
data_df['Total_Sales'] = data_df['Item_Sale'].apply(lambda x: x.split('$')[1]).astype(float)

data_df['Total_Sold'] = data_df['Total Sold'].astype(float)

# Convert string to datetime
data_df['Date'] = pd.to_datetime(data_df['Date Last Sold'])

# Apply the function to the column
data_df['Shipping'] = data_df['Avg Shipping'].apply(lambda x: extract_and_format(x)).astype(float)

data_df.drop(columns=['Unnamed: 0', 'Actions', 'Avg Sold Price', 'Bids', 'Date Last Sold', 'Avg Shipping', 'Item_Sale', 'Total Sold'], inplace=True)

data_df['Listing'] = data_df['Listing'].apply(lambda x: x.split('image')[-1])

# Apply the function to both listing titles and descriptions
data_df['Title_Keywords'] = data_df['Listing'].apply(extract_keywords)

data_df
# Out:
#                                                 Listing  Avg_Sold_Price  \
# 0     Innerzyme Vitamin K2 MK-7 300 mcg 30 CapsulesI...           30.34
# 1     NeuroCare Natural Brain Health Supplement Supp...           26.67
# 2     Super Beta Prostate Urinary Health 60 Caplets ...           21.42
# 3     GNC Probiotic Complex Daily Need with 10 Billi...           29.00
# 4     5-Pack Sight Care Vision Supplement PillsSuppo...           55.71
# ...                                                 ...             ...
# 1345  Reserveage Keratin Hair Booster with Biotin & ...           39.85
# 1346  ATHLETIC GREENS AG1 Comprehensive Daily Nutrit...           75.99
# 1347  Kokando Slimming Product (400 Tablets)Kokando ...           25.33
# 1348  NATURELO Raw Greens Superfood Powder - Unsweet...           39.00
# 1349  Standard Process - Immuplex - 150 CapsulesStan...           64.95
#
#       Total_Sales  Total_Sold       Date  Shipping  \
# 0           91.03         3.0 2024-03-19      0.00
# 1        26185.25       982.0 2024-03-19      0.31
# 2          256.98        12.0 2024-03-19      0.00
# 3           29.00         1.0 2024-03-19      0.00
# 4        20444.31       367.0 2024-03-19      0.00
# ...           ...         ...        ...       ...
# 1345        79.70         2.0 2024-03-18      0.00
# 1346       151.98         2.0 2024-03-18      0.33
# 1347      1392.95        55.0 2024-03-18      0.00
# 1348        39.00         1.0 2024-03-18      0.00
# 1349      2857.98        44.0 2024-03-18      0.00
#
#                                          Title_Keywords
# 0     [Innerzyme, Vitamin, K2, MK-7, mcg, CapsulesIn...
# 1     [NeuroCare, Natural, Brain, Health, Supplement...
# 2     [Super, Beta, Prostate, Urinary, Health, Caple...
# 3     [GNC, Probiotic, Complex, Daily, Need, Billion...
# 4     [5-Pack, Sight, Care, Vision, Supplement, Pill...
# ...                                                 ...
# 1345  [Reserveage, Keratin, Hair, Booster, Biotin, R...
# 1346  [ATHLETIC, GREENS, AG1, Comprehensive, Daily, ...
# 1347  [Kokando, Slimming, Product, Kokando, Slimming...
# 1348  [NATURELO, Raw, Greens, Superfood, Powder, Ser...
# 1349  [Standard, Process, Immuplex, CapsulesStandard...
#
# [1350 rows x 7 columns]

# %%
data_df['Month_Year'] = data_df['Date'].dt.strftime('%B %Y')

# %% [markdown]
# # Popular DF Whole

# %%
filtered_df= data_df.loc[data_df['Avg_Sold_Price'] > 10]
filtered_df
# Out:
#                                                 Listing  Avg_Sold_Price  \
# 0     Innerzyme Vitamin K2 MK-7 300 mcg 30 CapsulesI...           30.34
# 1     NeuroCare Natural Brain Health Supplement Supp...           26.67
# 2     Super Beta Prostate Urinary Health 60 Caplets ...           21.42
# 3     GNC Probiotic Complex Daily Need with 10 Billi...           29.00
# 4     5-Pack Sight Care Vision Supplement PillsSuppo...           55.71
# ...                                                 ...             ...
# 1345  Reserveage Keratin Hair Booster with Biotin & ...           39.85
# 1346  ATHLETIC GREENS AG1 Comprehensive Daily Nutrit...           75.99
# 1347  Kokando Slimming Product (400 Tablets)Kokando ...           25.33
# 1348  NATURELO Raw Greens Superfood Powder - Unsweet...           39.00
# 1349  Standard Process - Immuplex - 150 CapsulesStan...           64.95
#
#       Total_Sales  Total_Sold       Date  Shipping  \
# 0           91.03         3.0 2024-03-19      0.00
# 1        26185.25       982.0 2024-03-19      0.31
# 2          256.98        12.0 2024-03-19      0.00
# 3           29.00         1.0 2024-03-19      0.00
# 4        20444.31       367.0 2024-03-19      0.00
# ...           ...         ...        ...       ...
# 1345        79.70         2.0 2024-03-18      0.00
# 1346       151.98         2.0 2024-03-18      0.33
# 1347      1392.95        55.0 2024-03-18      0.00
# 1348        39.00         1.0 2024-03-18      0.00
# 1349      2857.98        44.0 2024-03-18      0.00
#
#                                          Title_Keywords  Month_Year
# 0     [Innerzyme, Vitamin, K2, MK-7, mcg, CapsulesIn...  March 2024
# 1     [NeuroCare, Natural, Brain, Health, Supplement...  March 2024
# 2     [Super, Beta, Prostate, Urinary, Health, Caple...  March 2024
# 3     [GNC, Probiotic, Complex, Daily, Need, Billion...  March 2024
# 4     [5-Pack, Sight, Care, Vision, Supplement, Pill...  March 2024
# ...                                                 ...         ...
# 1345  [Reserveage, Keratin, Hair, Booster, Biotin, R...  March 2024
# 1346  [ATHLETIC, GREENS, AG1, Comprehensive, Daily, ...  March 2024
# 1347  [Kokando, Slimming, Product, Kokando, Slimming...  March 2024
# 1348  [NATURELO, Raw, Greens, Superfood, Powder, Ser...  March 2024
# 1349  [Standard, Process, Immuplex, CapsulesStandard...  March 2024
#
# [1350 rows x 8 columns]

# %%
from collections import Counter

# %%
def extract_phrases(title):
    tokens = title.split()  # Tokenize the title
    phrases = []
    for i in range(len(tokens)):
        for j in range(i + 1, min(i + 6, len(tokens) + 1)):  # Generate combinations of 2 to 5 words
            phrase = ' '.join(tokens[i:j])
            if len(phrase.split()) >= 2 and len(phrase.split()) <= 5:  # Check if phrase length is between 2 and 5
                phrases.append(phrase)
    return phrases

# Apply the function to the Titles column
phrases = filtered_df['Listing'].apply(extract_phrases).sum()

# Count the occurrences of each phrase
phrase_counts = Counter(phrases)

# Find the most common phrases
most_common_phrases = phrase_counts.most_common()

most_common_phrases_df = pd.DataFrame(most_common_phrases, columns=['Name', 'Count'])
most_common_phrases_df.head(25)
# Out:
#                   Name  Count
# 0       Extra Strength    107
# 1            Vitamin C     79
# 2                 - 60     78
# 3           Capsules -     66
# 4           Vitamin D3     63
# 5              of Life     60
# 6   Dietary Supplement     56
# 7          60 Capsules     53
# 8          30 Capsules     50
# 9                - 120     50
# 10        120 Capsules     45
# 11                - 30     44
# 12        Vitamin Code     43
# 13            Fish Oil     42
# 14             AREDS 2     40
# 15        Supplement -     40
# 16        Life Vitamin     38
# 17           Soft Gels     36
# 18           Garden of     36
# 19   Life Vitamin Code     36
# 20          Whole Food     36
# 21      Garden of Life     35
# 22        180 Capsules     33
# 23         Eye Vitamin     33
# 24        Brain Health     32

# %%
type_product = most_common_phrases_df['Name'].head(100).tolist()

# %%
dict_sales = {'Phrase': [], 'Avg_Sold_Price_mean': [], 'Avg_Sold_Price_25': [], 'Avg_Sold_Price_75': [], 'Total_Sold': [], 'Ship_Cost': [], 'Count_Unique': []}


for phrase in type_product:
    # Filter rows where 'filtered_df' or 'Vitamin' is in the list
    temp_df = filtered_df[filtered_df['Listing'].apply(lambda x: phrase in x)]

    mean = temp_df.describe()['Avg_Sold_Price'].tolist()[1]

    percent_25 = temp_df.describe()['Avg_Sold_Price'].tolist()[4]

    percent_75 = temp_df.describe()['Avg_Sold_Price'].tolist()[6]

    total = temp_df['Total_Sold'].sum()

    ship = temp_df.describe()['Shipping'].tolist()[5]
    
    count =  temp_df.describe()['Total_Sold'].tolist()[0]
    
    dict_sales['Phrase'].append(phrase)
    dict_sales['Avg_Sold_Price_mean'].append(mean)
    dict_sales['Avg_Sold_Price_25'].append(percent_25)
    dict_sales['Avg_Sold_Price_75'].append(percent_75)
    dict_sales['Total_Sold'].append(total)
    dict_sales['Ship_Cost'].append(ship)
    dict_sales['Count_Unique'].append(count)
    
stats_df = pd.DataFrame.from_dict(dict_sales)

stats_df['Ratio_Sold_Count'] = stats_df['Total_Sold'] / stats_df['Count_Unique']

# %%
stats_df.sort_values(by='Avg_Sold_Price_mean', ascending=False).head(20)
# Out:
#                             Phrase  Avg_Sold_Price_mean  Avg_Sold_Price_25  \
# 80                    Joint Health            48.887000            34.3725
# 81               Health Supplement            46.396000            30.2500
# 30                 of Life Vitamin            46.370667            30.8600
# 31            of Life Vitamin Code            46.370667            30.8600
# 85          Garden of Life Vitamin            46.370667            30.8600
# 86     Garden of Life Vitamin Code            46.370667            30.8600
# 94          Strength 20mg Capsules            46.194444            40.0000
# 92    Extra Strength 20mg Capsules            46.194444            40.0000
# 93  Extra Strength 20mg Capsules -            46.194444            40.0000
# 99              20mg Capsules - 60            46.194444            40.0000
# 95        Strength 20mg Capsules -            46.194444            40.0000
# 96     Strength 20mg Capsules - 60            46.194444            40.0000
# 97                   20mg Capsules            46.194444            40.0000
# 98                 20mg Capsules -            46.194444            40.0000
# 44                     and Veggies            46.178462            32.9600
# 34                      Fruits and            46.178462            32.9600
# 5                          of Life            45.850333            29.9900
# 18                       Garden of            45.385000            29.9900
# 21                  Garden of Life            45.364138            29.9900
# 23                     Eye Vitamin            44.400000            24.9600
#
#     Avg_Sold_Price_75  Total_Sold  Ship_Cost  Count_Unique  Ratio_Sold_Count
# 80            54.3775      2039.0        0.0          10.0        203.900000
# 81            52.3550      1088.0        0.0          10.0        108.800000
# 30            57.4900        38.0        0.0          15.0          2.533333
# 31            57.4900        38.0        0.0          15.0          2.533333
# 85            57.4900        38.0        0.0          15.0          2.533333
# 86            57.4900        38.0        0.0          15.0          2.533333
# 94            49.9900        46.0        0.0           9.0          5.111111
# 92            49.9900        46.0        0.0           9.0          5.111111
# 93            49.9900        46.0        0.0           9.0          5.111111
# 99            49.9900        46.0        0.0           9.0          5.111111
# 95            49.9900        46.0        0.0           9.0          5.111111
# 96            49.9900        46.0        0.0           9.0          5.111111
# 97            49.9900        46.0        0.0           9.0          5.111111
# 98            49.9900        46.0        0.0           9.0          5.111111
# 44            38.2100      1357.0        0.0          13.0        104.384615
# 34            38.2100      1357.0        0.0          13.0        104.384615
# 5             57.9900       106.0        0.0          30.0          3.533333
# 18            53.7300       106.0        0.0          30.0          3.533333
# 21            54.9900       105.0        0.0          29.0          3.620690
# 23            46.2125      3904.0        0.0          30.0        130.133333

# %%
stats_df.sort_values(by='Total_Sold', ascending=False).head(20)
# Out:
#                 Phrase  Avg_Sold_Price_mean  Avg_Sold_Price_25  \
# 83           Vitamin D            30.796042            22.3575
# 4           Vitamin D3            29.837059            22.4325
# 3           Capsules -            34.693636            22.7200
# 23         Eye Vitamin            44.400000            24.9600
# 82            120 Caps            37.872045            26.5050
# 13            Fish Oil            28.244762            22.9900
# 1            Vitamin C            34.740845            23.7650
# 10        120 Capsules            37.808437            26.5050
# 0       Extra Strength            36.425636            24.9500
# 35             1000 mg            26.915882            22.9900
# 14             AREDS 2            36.423333            25.0000
# 6   Dietary Supplement            33.938485            23.9900
# 9                - 120            37.802222            24.7700
# 22        180 Capsules            34.874545            25.6025
# 77        Milk Thistle            25.761000            22.7300
# 42             Omega 3            35.866667            24.2000
# 80        Joint Health            48.887000            34.3725
# 48      Vegan Capsules            28.120000            22.9600
# 46             for Men            37.898750            26.0650
# 60         90 Capsules            39.304375            32.0350
#
#     Avg_Sold_Price_75  Total_Sold  Ship_Cost  Count_Unique  Ratio_Sold_Count
# 83            32.3775      6476.0        0.0          48.0        134.916667
# 4             31.6425      4521.0        0.0          34.0        132.970588
# 3             47.1700      4300.0        0.0          33.0        130.303030
# 23            46.2125      3904.0        0.0          30.0        130.133333
# 82            38.7850      3042.0        0.0          44.0         69.136364
# 13            29.9100      2876.0        0.0          21.0        136.952381
# 1             35.9100      2839.0        0.0          71.0         39.985915
# 10            37.8975      2591.0        0.0          32.0         80.968750
# 0             48.2500      2576.0        0.0          55.0         46.836364
# 35            29.9500      2491.0        0.0          17.0        146.529412
# 14            49.4500      2443.0        0.0          21.0        116.333333
# 6             37.1100      2394.0        0.0          33.0         72.545455
# 9             48.0250      2347.0        0.0          27.0         86.925926
# 22            39.9900      2331.0        0.0          22.0        105.954545
# 77            28.1675      2310.0        0.0          10.0        231.000000
# 42            40.9450      2096.0        0.0          15.0        139.733333
# 80            54.3775      2039.0        0.0          10.0        203.900000
# 48            30.1925      1936.0        0.0          16.0        121.000000
# 46            46.8550      1651.0        0.0          16.0        103.187500
# 60            44.7925      1499.0        0.0          16.0         93.687500

# %%
stats_df.sort_values(by='Ratio_Sold_Count', ascending=False).head(20)
# Out:
#                Phrase  Avg_Sold_Price_mean  Avg_Sold_Price_25  \
# 77       Milk Thistle            25.761000            22.7300
# 80       Joint Health            48.887000            34.3725
# 35            1000 mg            26.915882            22.9900
# 42            Omega 3            35.866667            24.2000
# 13           Fish Oil            28.244762            22.9900
# 83          Vitamin D            30.796042            22.3575
# 4          Vitamin D3            29.837059            22.4325
# 3          Capsules -            34.693636            22.7200
# 23        Eye Vitamin            44.400000            24.9600
# 48     Vegan Capsules            28.120000            22.9600
# 14            AREDS 2            36.423333            25.0000
# 81  Health Supplement            46.396000            30.2500
# 22       180 Capsules            34.874545            25.6025
# 44        and Veggies            46.178462            32.9600
# 34         Fruits and            46.178462            32.9600
# 46            for Men            37.898750            26.0650
# 60        90 Capsules            39.304375            32.0350
# 58   Multivitamin for            34.326154            28.3700
# 40    Supplement with            34.229286            33.1100
# 9               - 120            37.802222            24.7700
#
#     Avg_Sold_Price_75  Total_Sold  Ship_Cost  Count_Unique  Ratio_Sold_Count
# 77            28.1675      2310.0        0.0          10.0        231.000000
# 80            54.3775      2039.0        0.0          10.0        203.900000
# 35            29.9500      2491.0        0.0          17.0        146.529412
# 42            40.9450      2096.0        0.0          15.0        139.733333
# 13            29.9100      2876.0        0.0          21.0        136.952381
# 83            32.3775      6476.0        0.0          48.0        134.916667
# 4             31.6425      4521.0        0.0          34.0        132.970588
# 3             47.1700      4300.0        0.0          33.0        130.303030
# 23            46.2125      3904.0        0.0          30.0        130.133333
# 48            30.1925      1936.0        0.0          16.0        121.000000
# 14            49.4500      2443.0        0.0          21.0        116.333333
# 81            52.3550      1088.0        0.0          10.0        108.800000
# 22            39.9900      2331.0        0.0          22.0        105.954545
# 44            38.2100      1357.0        0.0          13.0        104.384615
# 34            38.2100      1357.0        0.0          13.0        104.384615
# 46            46.8550      1651.0        0.0          16.0        103.187500
# 60            44.7925      1499.0        0.0          16.0         93.687500
# 58            38.6500      1206.0        0.0          13.0         92.769231
# 40            36.3000      1226.0        0.0          14.0         87.571429
# 9             48.0250      2347.0        0.0          27.0         86.925926
