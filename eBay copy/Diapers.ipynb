# %%
import pandas as pd

# %% [markdown]
# # Diapers

# %%
data_df= pd.read_csv('diapers.csv')
data_df
# Out:
#       Unnamed: 0                                            Listing  \
# 0              0  , preview full size imagePampers Swaddlers Act...
# 1              1  , preview full size imageDiapers Size 6 124 Co...
# 2              2  , preview full size imageSize 5: 27lbs and up,...
# 3              3  , preview full size imageHuggies Size 4 Diaper...
# 4              4  , preview full size imagePampers Swaddlers Dia...
# ...          ...                                                ...
# 5695          45  , preview full size imageNIB Parent's Choice S...
# 5696          46  , preview full size imagePampers Baby Dry 37 c...
# 5697          47  , preview full size imagePampers Baby Dry Disp...
# 5698          48  , preview full size imagePampers Baby-Dry Extr...
# 5699          49  , preview full size imageBaby Diapers Size 1, ...
#
#                               Actions     Avg Sold Price  \
# 0     EditSell SimilarExclude listing  $34.05Fixed price
# 1     EditSell SimilarExclude listing  $34.47Fixed price
# 2     EditSell SimilarExclude listing  $57.99Fixed price
# 3     EditSell SimilarExclude listing  $32.40Fixed price
# 4     EditSell SimilarExclude listing  $19.99Fixed price
# ...                               ...                ...
# 5695              EditExclude listing   $2.37Fixed price
# 5696              EditExclude listing  $15.00Fixed price
# 5697              EditExclude listing  $32.99Fixed price
# 5698              EditExclude listing  $47.38Fixed price
# 5699              EditExclude listing  $53.32Fixed price
#
#                  Avg Shipping Total Sold  Item_Sale Bids Date Last Sold
# 0     $0.00100% Free shipping        203  $6,912.46    –   Mar 19, 2024
# 1     $0.00100% Free shipping          2     $68.94    –   Mar 19, 2024
# 2     $0.00100% Free shipping         21  $1,217.79    –   Mar 19, 2024
# 3     $0.00100% Free shipping          2     $64.80    –   Mar 19, 2024
# 4     $0.00100% Free shipping          1     $19.99    –   Mar 19, 2024
# ...                       ...        ...        ...  ...            ...
# 5695    $7.700% Free shipping          1      $2.37    –    Jan 4, 2022
# 5696  $0.00100% Free shipping          1     $15.00    –    Jan 4, 2022
# 5697  $0.00100% Free shipping          1     $32.99    –    Jan 4, 2022
# 5698  $0.00100% Free shipping         17    $805.39    –    Jan 3, 2022
# 5699  $0.00100% Free shipping          1     $53.32    –    Jan 3, 2022
#
# [5700 rows x 9 columns]

# %%
# Function to extract and format the first part of the string
def extract_and_format(value):
    parts = value.split('%')[0].split('$')[1]
    first_part = parts.strip()
    formatted_value = '{:.2f}'.format(float(first_part[1:]))
    return formatted_value

# %%
# Remove commas from all values in the DataFrame
data_df = data_df.replace(',', '', regex=True)
# 
data_df['Avg_Sold_Price'] = data_df['Avg Sold Price'].apply(lambda x: x.split('$')[1].split('F')[0].split('A')[0]).astype(float)

# 
data_df['Total_Sales'] = data_df['Item_Sale'].apply(lambda x: x.split('$')[1]).astype(float)

data_df['Total_Sold'] = data_df['Total Sold'].astype(float)

# Convert string to datetime
data_df['Date'] = pd.to_datetime(data_df['Date Last Sold'])

# Apply the function to the column
data_df['Shipping'] = data_df['Avg Shipping'].apply(lambda x: extract_and_format(x)).astype(float)

data_df.head()
# Out:
#    Unnamed: 0                                            Listing  \
# 0           0   preview full size imagePampers Swaddlers Acti...
# 1           1   preview full size imageDiapers Size 6 124 Cou...
# 2           2   preview full size imageSize 5: 27lbs and up 1...
# 3           3   preview full size imageHuggies Size 4 Diapers...
# 4           4   preview full size imagePampers Swaddlers Diap...
#
#                            Actions     Avg Sold Price  \
# 0  EditSell SimilarExclude listing  $34.05Fixed price
# 1  EditSell SimilarExclude listing  $34.47Fixed price
# 2  EditSell SimilarExclude listing  $57.99Fixed price
# 3  EditSell SimilarExclude listing  $32.40Fixed price
# 4  EditSell SimilarExclude listing  $19.99Fixed price
#
#               Avg Shipping Total Sold Item_Sale Bids Date Last Sold  \
# 0  $0.00100% Free shipping        203  $6912.46    –    Mar 19 2024
# 1  $0.00100% Free shipping          2    $68.94    –    Mar 19 2024
# 2  $0.00100% Free shipping         21  $1217.79    –    Mar 19 2024
# 3  $0.00100% Free shipping          2    $64.80    –    Mar 19 2024
# 4  $0.00100% Free shipping          1    $19.99    –    Mar 19 2024
#
#    Avg_Sold_Price  Total_Sales  Total_Sold       Date  Shipping
# 0           34.05      6912.46       203.0 2024-03-19       0.0
# 1           34.47        68.94         2.0 2024-03-19       0.0
# 2           57.99      1217.79        21.0 2024-03-19       0.0
# 3           32.40        64.80         2.0 2024-03-19       0.0
# 4           19.99        19.99         1.0 2024-03-19       0.0

# %%
data_df.drop(columns=['Unnamed: 0', 'Actions', 'Avg Sold Price', 'Bids', 'Date Last Sold', 'Avg Shipping', 'Item_Sale', 'Total Sold'], inplace=True)
data_df.head()
# Out:
#                                              Listing  Avg_Sold_Price  \
# 0   preview full size imagePampers Swaddlers Acti...           34.05
# 1   preview full size imageDiapers Size 6 124 Cou...           34.47
# 2   preview full size imageSize 5: 27lbs and up 1...           57.99
# 3   preview full size imageHuggies Size 4 Diapers...           32.40
# 4   preview full size imagePampers Swaddlers Diap...           19.99
#
#    Total_Sales  Total_Sold       Date  Shipping
# 0      6912.46       203.0 2024-03-19       0.0
# 1        68.94         2.0 2024-03-19       0.0
# 2      1217.79        21.0 2024-03-19       0.0
# 3        64.80         2.0 2024-03-19       0.0
# 4        19.99         1.0 2024-03-19       0.0

# %%
data_df['Listing'] = data_df['Listing'].apply(lambda x: x.split('image')[-1])

# %%
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag

# Download NLTK resources (only need to do this once)
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

# Function to extract keywords
def extract_keywords(text):
    tokens = word_tokenize(text)
    tagged_tokens = pos_tag(tokens)
    keywords = [word for word, pos in tagged_tokens if pos in ['NN', 'NNS', 'NNP', 'JJ']]
    return keywords
# Out:
# [nltk_data] Downloading package punkt to /Users/evanbruno/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/evanbruno/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
# Apply the function to both listing titles and descriptions
data_df['Title_Keywords'] = data_df['Listing'].apply(extract_keywords)
data_df
# Out:
#                                                 Listing  Avg_Sold_Price  \
# 0     Pampers Swaddlers Active Baby Diapers Enormous...           34.05
# 1      Diapers Size 6 124 CountDiapers Size 6 124 Count           34.47
# 2     Size 5: 27lbs and up 168 Count Kirkland Signat...           57.99
# 3     Huggies Size 4 Diapers Little Movers Baby Diap...           32.40
# 4     Pampers Swaddlers Diapers Size 1 96 CountPampe...           19.99
# ...                                                 ...             ...
# 5695  NIB Parent's Choice Size One DiapersNIB Parent...            2.37
# 5696  Pampers Baby Dry 37 ct Diapers  - White - Size...           15.00
# 5697  Pampers Baby Dry Disposable Diapers NEWBORN SI...           32.99
# 5698  Pampers Baby-Dry Extra Protection Diapers - Ne...           47.38
# 5699  Baby Diapers Size 1 198 Ct Huggies Little Snug...           53.32
#
#       Total_Sales  Total_Sold       Date  Shipping  \
# 0         6912.46       203.0 2024-03-19       0.0
# 1           68.94         2.0 2024-03-19       0.0
# 2         1217.79        21.0 2024-03-19       0.0
# 3           64.80         2.0 2024-03-19       0.0
# 4           19.99         1.0 2024-03-19       0.0
# ...           ...         ...        ...       ...
# 5695         2.37         1.0 2022-01-04       0.7
# 5696        15.00         1.0 2022-01-04       0.0
# 5697        32.99         1.0 2022-01-04       0.0
# 5698       805.39        17.0 2022-01-03       0.0
# 5699        53.32         1.0 2022-01-03       0.0
#
#                                          Title_Keywords
# 0     [Pampers, Swaddlers, Active, Baby, Diapers, En...
# 1                                [Diapers, Size, Count]
# 2     [Size, Count, Kirkland, Signature, Diapers, Co...
# 3     [Huggies, Diapers, Little, Movers, Baby, Diape...
# 4            [Pampers, Swaddlers, Diapers, Size, Count]
# ...                                                 ...
# 5695  [NIB, Parent, Choice, Size, DiapersNIB, Parent...
# 5696  [Pampers, Baby, Dry, ct, Diapers, White, Size,...
# 5697  [Pampers, Baby, Dry, Disposable, Diapers, NEWB...
# 5698  [Pampers, Baby-Dry, Extra, Protection, Diapers...
# 5699  [Baby, Diapers, Size, Ct, Huggies, Little, Snu...
#
# [5700 rows x 7 columns]

# %% [markdown]
# # Trends

# %%
data_df['Month_Year'] = data_df['Date'].dt.strftime('%B %Y')

avg_sold = data_df.groupby(by='Month_Year').mean()['Avg_Sold_Price']

total_sold = data_df.groupby(by='Month_Year').sum()['Total_Sold']

total_sales = data_df.groupby(by='Month_Year').sum()['Total_Sales']

count = data_df.groupby(by='Month_Year').count()['Total_Sales']

unique = data_df.groupby(['Month_Year'])['Listing'].nunique()

trend_dict = {'Avg_Sold': avg_sold, 'Total_Sold': total_sold, 'Total_Sales': total_sales, 'Count': count, 'Unique_Listings': unique}

trend_df = pd.DataFrame.from_dict(trend_dict)

trend_df['Date'] = pd.to_datetime(trend_df.index)
trend_df = trend_df.sort_values(by='Date')

trend_df
# Out:
# /var/folders/g3/164q6cz52jv0sjllnsg7jdsm0000gn/T/ipykernel_3954/2613833271.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   avg_sold = data_df.groupby(by='Month_Year').mean()['Avg_Sold_Price']
# /var/folders/g3/164q6cz52jv0sjllnsg7jdsm0000gn/T/ipykernel_3954/2613833271.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   total_sold = data_df.groupby(by='Month_Year').sum()['Total_Sold']
# /var/folders/g3/164q6cz52jv0sjllnsg7jdsm0000gn/T/ipykernel_3954/2613833271.py:7: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   total_sales = data_df.groupby(by='Month_Year').sum()['Total_Sales']
#                  Avg_Sold  Total_Sold  Total_Sales  Count  Unique_Listings  \
# Month_Year
# January 2022    35.471185       861.0     24128.11    135              133
# February 2022   39.905926       573.0     23204.90    108              102
# March 2022      35.460569       736.0     27549.95    123              121
# April 2022      33.366953       453.0     15117.74    128              123
# May 2022        37.724539       492.0     19346.87    141              137
# June 2022       36.301958       762.0     29569.97    143              137
# July 2022       37.291149       890.0     37117.27    148              142
# August 2022     36.206444       923.0     34824.50    135              130
# September 2022  33.795455      1013.0     31031.48    154              151
# October 2022    34.543464      1505.0     56187.54    153              148
# November 2022   34.962980      2585.0     67281.89    151              147
# December 2022   36.292051       920.0     38504.44    117              115
# January 2023    34.950719      1372.0     59302.43    139              135
# February 2023   38.031712       976.0     31943.59    146              143
# March 2023      44.050305       433.0     18024.11    131              131
# April 2023      33.164046       688.0     26243.89    131              127
# May 2023        32.057083       600.0     25428.49    144              141
# June 2023       37.300208      2026.0     72283.10    240              227
# July 2023       33.386692      1287.0     41898.91    266              251
# August 2023     32.928311      1170.0     45350.94    296              266
# September 2023  32.700961      2622.0     72441.36    281              263
# October 2023    30.889524      1043.0     43863.91    336              307
# November 2023   31.690291      1096.0     31489.17    344              318
# December 2023   28.713815       870.0     23479.53    346              329
# January 2024    29.787033      1377.0     44420.69    418              372
# February 2024   31.743620      3825.0     97660.77    395              369
# March 2024      31.177517     12968.0    409216.24    451              417
#
#                      Date
# Month_Year
# January 2022   2022-01-01
# February 2022  2022-02-01
# March 2022     2022-03-01
# April 2022     2022-04-01
# May 2022       2022-05-01
# June 2022      2022-06-01
# July 2022      2022-07-01
# August 2022    2022-08-01
# September 2022 2022-09-01
# October 2022   2022-10-01
# November 2022  2022-11-01
# December 2022  2022-12-01
# January 2023   2023-01-01
# February 2023  2023-02-01
# March 2023     2023-03-01
# April 2023     2023-04-01
# May 2023       2023-05-01
# June 2023      2023-06-01
# July 2023      2023-07-01
# August 2023    2023-08-01
# September 2023 2023-09-01
# October 2023   2023-10-01
# November 2023  2023-11-01
# December 2023  2023-12-01
# January 2024   2024-01-01
# February 2024  2024-02-01
# March 2024     2024-03-01

# %%
data_df['Month_Year'] = data_df['Date'].dt.strftime('%B %Y')

avg_sold = data_df.groupby(by='Month_Year').mean()['Avg_Sold_Price']

total_sold = data_df.groupby(by='Month_Year').sum()['Total_Sold']

total_sales = data_df.groupby(by='Month_Year').sum()['Total_Sales']

count = data_df.groupby(by='Month_Year').count()['Total_Sales']

trend_dict = {'Avg_Sold': avg_sold, 'Total_Sold': total_sold, 'Total_Sales': total_sales, 'Count': count}

trend_df = pd.DataFrame.from_dict(trend_dict)

trend_df['Date'] = pd.to_datetime(trend_df.index)
trend_df = trend_df.sort_values(by='Date')

trend_df
# Out:
# /var/folders/g3/164q6cz52jv0sjllnsg7jdsm0000gn/T/ipykernel_2078/2835948711.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   avg_sold = data_df.groupby(by='Month_Year').mean()['Avg_Sold_Price']
# /var/folders/g3/164q6cz52jv0sjllnsg7jdsm0000gn/T/ipykernel_2078/2835948711.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   total_sold = data_df.groupby(by='Month_Year').sum()['Total_Sold']
# /var/folders/g3/164q6cz52jv0sjllnsg7jdsm0000gn/T/ipykernel_2078/2835948711.py:7: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   total_sales = data_df.groupby(by='Month_Year').sum()['Total_Sales']
#                  Avg_Sold  Total_Sold  Total_Sales  Count       Date
# Month_Year
# January 2022    35.471185       861.0     24128.11    135 2022-01-01
# February 2022   39.905926       573.0     23204.90    108 2022-02-01
# March 2022      35.460569       736.0     27549.95    123 2022-03-01
# April 2022      33.366953       453.0     15117.74    128 2022-04-01
# May 2022        37.724539       492.0     19346.87    141 2022-05-01
# June 2022       36.301958       762.0     29569.97    143 2022-06-01
# July 2022       37.291149       890.0     37117.27    148 2022-07-01
# August 2022     36.206444       923.0     34824.50    135 2022-08-01
# September 2022  33.795455      1013.0     31031.48    154 2022-09-01
# October 2022    34.543464      1505.0     56187.54    153 2022-10-01
# November 2022   34.962980      2585.0     67281.89    151 2022-11-01
# December 2022   36.292051       920.0     38504.44    117 2022-12-01
# January 2023    34.950719      1372.0     59302.43    139 2023-01-01
# February 2023   38.031712       976.0     31943.59    146 2023-02-01
# March 2023      44.050305       433.0     18024.11    131 2023-03-01
# April 2023      33.164046       688.0     26243.89    131 2023-04-01
# May 2023        32.057083       600.0     25428.49    144 2023-05-01
# June 2023       37.300208      2026.0     72283.10    240 2023-06-01
# July 2023       33.386692      1287.0     41898.91    266 2023-07-01
# August 2023     32.928311      1170.0     45350.94    296 2023-08-01
# September 2023  32.700961      2622.0     72441.36    281 2023-09-01
# October 2023    30.889524      1043.0     43863.91    336 2023-10-01
# November 2023   31.690291      1096.0     31489.17    344 2023-11-01
# December 2023   28.713815       870.0     23479.53    346 2023-12-01
# January 2024    29.787033      1377.0     44420.69    418 2024-01-01
# February 2024   31.743620      3825.0     97660.77    395 2024-02-01
# March 2024      31.177517     12968.0    409216.24    451 2024-03-01

# %%
from matplotlib import pyplot as plt

# %%
# Plotting the lines
plt.plot(trend_df.index, trend_df['Avg_Sold'], label='Line 1')

# Adding labels and title
plt.xlabel('Time')
plt.ylabel('$ Dollars')
plt.title('Avg_Sold')
plt.xticks(rotation=50) 

# Adding legend
plt.legend()

# Display the plot
plt.show()

# %%
# Plotting the lines
plt.plot(trend_df.index, trend_df['Total_Sales'], label='Line 1')

# Adding labels and title
plt.xlabel('Time')
plt.ylabel('$ Dollars')
plt.title('Total_Sales')
plt.xticks(rotation=50) 

# Adding legend
plt.legend()

# Display the plot
plt.show()

# %%
# Plotting the lines
plt.plot(trend_df.index, trend_df['Count'], label='Line 1')

# Adding labels and title
plt.xlabel('Time')
plt.ylabel('$ Dollars')
plt.title('Count')
plt.xticks(rotation=50) 

# Adding legend
plt.legend()

# Display the plot
plt.show()

# %%
data_df['Month'] = data_df['Date'].dt.month

avg_sold = data_df.groupby(by='Month').mean()['Avg_Sold_Price']

total_sold = data_df.groupby(by='Month').sum()['Total_Sold']

total_sales = data_df.groupby(by='Month').sum()['Total_Sales']

trend_dict = {'Avg_Sold': avg_sold, 'Total_Sold': total_sold, 'Total_Sales': total_sales}

trend_df = pd.DataFrame.from_dict(trend_dict)
trend_df
# Out:
# /var/folders/g3/164q6cz52jv0sjllnsg7jdsm0000gn/T/ipykernel_2078/546015248.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   avg_sold = data_df.groupby(by='Month').mean()['Avg_Sold_Price']
# /var/folders/g3/164q6cz52jv0sjllnsg7jdsm0000gn/T/ipykernel_2078/546015248.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   total_sold = data_df.groupby(by='Month').sum()['Total_Sold']
# /var/folders/g3/164q6cz52jv0sjllnsg7jdsm0000gn/T/ipykernel_2078/546015248.py:7: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   total_sales = data_df.groupby(by='Month').sum()['Total_Sales']
#         Avg_Sold  Total_Sold  Total_Sales
# Month
# 1      31.933150      3610.0    127851.23
# 2      34.516487      5374.0    152809.26
# 3      34.316738     14137.0    454790.30
# 4      33.264324      1141.0     41361.63
# 5      34.860982      1092.0     44775.36
# 6      36.927493      2788.0    101853.07
# 7      34.782488      2177.0     79016.18
# 8      33.955104      2093.0     80175.44
# 9      33.088437      3635.0    103472.84
# 10     32.032781      2548.0    100051.45
# 11     32.688626      3681.0     98771.06
# 12     30.628834      1790.0     61983.97

# %%
# Plotting the lines
plt.plot(trend_df.index, trend_df['Avg_Sold'], label='Line 1')

# Adding labels and title
plt.xlabel('Time')
plt.ylabel('$ Dollars')
plt.title('Avg_Sold')

# Adding legend
plt.legend()

# Display the plot
plt.show()

# %%
# Plotting the lines
plt.plot(trend_df.index, trend_df['Total_Sales'], label='Line 1')

# Adding labels and title
plt.xlabel('Time')
plt.ylabel('$ Dollars')
plt.title('Total_Sales')

# Adding legend
plt.legend()

# Display the plot
plt.show()

# %% [markdown]
# # Popular Whole DF

# %%
filtered_df= data_df.loc[data_df['Avg_Sold_Price'] > 10]
filtered_df.head()
# Out:
#                                              Listing  Avg_Sold_Price  \
# 0  Pampers Swaddlers Active Baby Diapers Enormous...           34.05
# 1   Diapers Size 6 124 CountDiapers Size 6 124 Count           34.47
# 2  Size 5: 27lbs and up 168 Count Kirkland Signat...           57.99
# 3  Huggies Size 4 Diapers Little Movers Baby Diap...           32.40
# 4  Pampers Swaddlers Diapers Size 1 96 CountPampe...           19.99
#
#    Total_Sales  Total_Sold       Date  Shipping  \
# 0      6912.46       203.0 2024-03-19       0.0
# 1        68.94         2.0 2024-03-19       0.0
# 2      1217.79        21.0 2024-03-19       0.0
# 3        64.80         2.0 2024-03-19       0.0
# 4        19.99         1.0 2024-03-19       0.0
#
#                                       Title_Keywords
# 0  [Pampers, Swaddlers, Active, Baby, Diapers, En...
# 1                             [Diapers, Size, Count]
# 2  [Size, Count, Kirkland, Signature, Diapers, Co...
# 3  [Huggies, Diapers, Little, Movers, Baby, Diape...
# 4         [Pampers, Swaddlers, Diapers, Size, Count]

# %%
from collections import Counter
# Flatten the filtered lists
data_df_lists = filtered_df['Title_Keywords'].sum()

# Count the occurrences of each word
word_counts = Counter(data_df_lists)

# Find the most common words
most_common_words = word_counts.most_common()

# %%
def extract_phrases(title):
    tokens = title.split()  # Tokenize the title
    phrases = []
    for i in range(len(tokens)):
        for j in range(i + 1, min(i + 6, len(tokens) + 1)):  # Generate combinations of 2 to 5 words
            phrase = ' '.join(tokens[i:j])
            if len(phrase.split()) >= 2 and len(phrase.split()) <= 5:  # Check if phrase length is between 2 and 5
                phrases.append(phrase)
    return phrases

# Apply the function to the Titles column
phrases = filtered_df['Listing'].apply(extract_phrases).sum()

# Count the occurrences of each phrase
phrase_counts = Counter(phrases)

# Find the most common phrases
most_common_phrases = phrase_counts.most_common()

most_common_phrases_df = pd.DataFrame(most_common_phrases, columns=['Name', 'Count'])
most_common_phrases_df.head(25)
# Out:
#                   Name  Count
# 0         Diapers Size   5159
# 1         Baby Diapers   2611
# 2    Baby Diapers Size   1672
# 3               Size 4   1220
# 4   Disposable Diapers   1218
# 5               Size 3   1157
# 6               Size 5   1096
# 7               Size 1   1077
# 8               Size 6   1049
# 9               - Size    986
# 10              Size 2    945
# 11            Baby Dry    885
# 12   Pampers Swaddlers    808
# 13    Little Snugglers    784
# 14      Diapers Size 4    782
# 15      Diapers Size 3    749
# 16      Huggies Little    737
# 17       Little Movers    720
# 18           Diapers -    710
# 19   Swaddlers Diapers    679
# 20      Diapers Size 1    646
# 21      Diapers Size 6    639
# 22      Diapers Size 5    629
# 23      Diapers Size 2    604
# 24         Dry Diapers    573

# %%
type_product = most_common_phrases_df['Name'].head(20).tolist()
type_product
# Out:
# ['Diapers Size',
#  'Baby Diapers',
#  'Baby Diapers Size',
#  'Size 4',
#  'Disposable Diapers',
#  'Size 3',
#  'Size 5',
#  'Size 1',
#  'Size 6',
#  '- Size',
#  'Size 2',
#  'Baby Dry',
#  'Pampers Swaddlers',
#  'Little Snugglers',
#  'Diapers Size 4',
#  'Diapers Size 3',
#  'Huggies Little',
#  'Little Movers',
#  'Diapers -',
#  'Swaddlers Diapers']

# %%
dict_sales = {'Phrase': [], 'Avg_Sold_Price_mean': [], 'Avg_Sold_Price_25': [], 'Avg_Sold_Price_75': [], 'Total_Sold': [], 'Ship_Cost': []}

# %%
for phrase in type_product:
    # Filter rows where 'vitamin' or 'Vitamin' is in the list
    temp_df = data_df[data_df['Listing'].apply(lambda x: phrase in x)]

    mean = temp_df.describe()['Avg_Sold_Price'].tolist()[1]

    percent_25 = temp_df.describe()['Avg_Sold_Price'].tolist()[4]

    percent_75 = temp_df.describe()['Avg_Sold_Price'].tolist()[6]

    count = temp_df.describe()['Total_Sold'].tolist()[0]

    ship = temp_df.describe()['Shipping'].tolist()[5]
    
    dict_sales['Phrase'].append(phrase)
    dict_sales['Avg_Sold_Price_mean'].append(mean)
    dict_sales['Avg_Sold_Price_25'].append(percent_25)
    dict_sales['Avg_Sold_Price_75'].append(percent_75)
    dict_sales['Total_Sold'].append(count)
    dict_sales['Ship_Cost'].append(ship)
    
pd.DataFrame.from_dict(dict_sales)
# Out:
#                 Phrase  Avg_Sold_Price_mean  Avg_Sold_Price_25  \
# 0         Diapers Size            33.814650            19.9900
# 1         Baby Diapers            33.951553            19.3900
# 2    Baby Diapers Size            34.214918            19.0000
# 3               Size 4            35.182114            22.4450
# 4   Disposable Diapers            34.206483            21.7250
# 5               Size 3            31.611944            19.2675
# 6               Size 5            34.953130            20.9900
# 7               Size 1            32.090106            18.9975
# 8               Size 6            35.719879            20.7000
# 9               - Size            30.903790            20.9900
# 10              Size 2            30.320410            17.9900
# 11            Baby Dry            38.812436            25.9975
# 12   Pampers Swaddlers            34.876612            22.9900
# 13    Little Snugglers            31.309357            15.0000
# 14      Diapers Size 4            36.775561            24.2975
# 15      Diapers Size 3            32.962306            19.9425
# 16      Huggies Little            35.665295            19.9900
# 17       Little Movers            42.515753            25.3375
# 18           Diapers -            32.169947            20.7800
# 19   Swaddlers Diapers            35.094907            22.4900
#
#     Avg_Sold_Price_75  Total_Sold  Ship_Cost
# 0             44.0000      2873.0        0.0
# 1             45.0000      1507.0        0.0
# 2             45.0000       917.0        0.0
# 3             44.9550       700.0        0.0
# 4             42.1300       691.0        0.0
# 5             40.0000       684.0        0.0
# 6             42.1250       591.0        0.0
# 7             40.9925       660.0        0.0
# 8             44.9900       577.0        0.0
# 9             37.6300       533.0        0.0
# 10            39.7300       537.0        0.0
# 11            49.9525       468.0        0.0
# 12            44.9500       729.0        0.0
# 13            41.9600       451.0        0.0
# 14            47.9875       446.0        0.0
# 15            42.2025       438.0        0.0
# 16            49.9700       695.0        0.0
# 17            59.9900       372.0        0.0
# 18            41.9900       377.0        0.0
# 19            46.5200       375.0        0.0

# %% [markdown]
# # Brands Analysis

# %%
# Filter the DataFrame
testing_df = filtered_df[filtered_df['Listing'].str.contains('Pampers Swaddlers')]
testing_df
# Out:
#                                                 Listing  Avg_Sold_Price  \
# 0     Pampers Swaddlers Active Baby Diapers Enormous...           34.05
# 4     Pampers Swaddlers Diapers Size 1 96 CountPampe...           19.99
# 8     Pampers Swaddlers Active Baby Diapers - Size 1...           28.00
# 10    Pampers Swaddlers Diapers - Size 2 84 Count Ul...           36.67
# 11    Pampers Swaddlers Diapers Size 2 84 CountPampe...           24.84
# ...                                                 ...             ...
# 5656  Pampers Swaddlers Diapers Size 2 -186 ct. (12-...           29.13
# 5657  Pampers Swaddlers Disposable Baby Diapers Size...           68.32
# 5668  Pampers Swaddlers Size 1 (8-14 lbs) Baby Diape...           23.99
# 5676  Damaged Pampers Swaddlers Active Baby Diapers ...           30.00
# 5679  Pampers Swaddlers Diapers Size 5 (27+ Pounds) ...           43.70
#
#       Total_Sales  Total_Sold       Date  Shipping  \
# 0         6912.46       203.0 2024-03-19       0.0
# 4           19.99         1.0 2024-03-19       0.0
# 8           28.00         1.0 2024-03-19       0.0
# 10          36.67         1.0 2024-03-19       0.0
# 11          24.84         1.0 2024-03-19       0.0
# ...           ...         ...        ...       ...
# 5656       611.79        21.0 2022-01-13       0.0
# 5657       204.97         3.0 2022-01-13       0.0
# 5668        23.99         1.0 2022-01-09       0.0
# 5676       120.00         4.0 2022-01-08       0.0
# 5679       305.93         7.0 2022-01-07       0.0
#
#                                          Title_Keywords
# 0     [Pampers, Swaddlers, Active, Baby, Diapers, En...
# 4            [Pampers, Swaddlers, Diapers, Size, Count]
# 8     [Pampers, Swaddlers, Active, Baby, Diapers, Si...
# 10    [Pampers, Swaddlers, Diapers, Size, Count, Ult...
# 11           [Pampers, Swaddlers, Diapers, Size, Count]
# ...                                                 ...
# 5656  [Pampers, Swaddlers, Diapers, Size, -186, ct.,...
# 5657  [Pampers, Swaddlers, Disposable, Baby, Diapers...
# 5668  [Pampers, Swaddlers, lbs, Baby, Diapers, Count...
# 5676  [Pampers, Swaddlers, Active, Baby, Diapers, Si...
# 5679  [Pampers, Swaddlers, Diapers, Size, Pounds, Po...
#
# [690 rows x 7 columns]

# %%
# Apply the function to the Titles column
phrases = testing_df['Listing'].apply(extract_phrases).sum()

# Count the occurrences of each phrase
phrase_counts = Counter(phrases)

# Find the most common phrases
most_common_phrases = phrase_counts.most_common()

# %%
most_common_phrases_df = pd.DataFrame(most_common_phrases, columns=['Name', 'Count'])
most_common_phrases_df.head(25)
# Out:
#                                     Name  Count
# 0                      Pampers Swaddlers    808
# 1                           Diapers Size    682
# 2                      Swaddlers Diapers    646
# 3                 Swaddlers Diapers Size    372
# 4              Pampers Swaddlers Diapers    346
# 5                   Swaddlers Disposable    325
# 6                           Baby Diapers    232
# 7                     Disposable Diapers    222
# 8           Pampers Swaddlers Disposable    221
# 9                                 - Size    208
# 10        Pampers Swaddlers Diapers Size    201
# 11                       Disposable Baby    194
# 12                                Size 4    178
# 13          Swaddlers Disposable Diapers    176
# 14                                Size 1    156
# 15                               Count -    138
# 16                                Size 2    136
# 17                CountPampers Swaddlers    133
# 18                             Diapers -    130
# 19                                Size 6    126
# 20                                Size 3    121
# 21               Disposable Baby Diapers    118
# 22                        Diapers Size 4    117
# 23                           Active Baby    113
# 24  Pampers Swaddlers Disposable Diapers    107

# %%
# Filter the column containing the word "size"
size_df = most_common_phrases_df[most_common_phrases_df['Name'].str.contains('size')]

type_product = size_df.head(20)['Name'].tolist()

# %%
dict_sales = {'Phrase': [], 'Avg_Sold_Price_mean': [], 'Avg_Sold_Price_25': [], 'Avg_Sold_Price_75': [], 'Total_Sold': [], 'Ship_Cost': []}

# %%
for phrase in type_product:
    # Filter rows where 'vitamin' or 'Vitamin' is in the list
    temp_df = testing_df[testing_df['Listing'].apply(lambda x: phrase in x)]

    mean = temp_df.describe()['Avg_Sold_Price'].tolist()[1]

    percent_25 = temp_df.describe()['Avg_Sold_Price'].tolist()[4]

    percent_75 = temp_df.describe()['Avg_Sold_Price'].tolist()[6]

    count = temp_df.describe()['Total_Sold'].tolist()[0]

    ship = temp_df.describe()['Shipping'].tolist()[5]
    
    dict_sales['Phrase'].append(phrase)
    dict_sales['Avg_Sold_Price_mean'].append(mean)
    dict_sales['Avg_Sold_Price_25'].append(percent_25)
    dict_sales['Avg_Sold_Price_75'].append(percent_75)
    dict_sales['Total_Sold'].append(count)
    dict_sales['Ship_Cost'].append(ship)
    
pd.DataFrame.from_dict(dict_sales)
# Out:
#                                  Phrase  Avg_Sold_Price_mean  \
# 0                Swaddlers Diapers size            50.419444
# 1                          Diapers size            45.505000
# 2        Pampers Swaddlers Diapers size            50.419444
# 3    lb.)Pampers Swaddlers Diapers size            60.015455
# 4                                size 4            50.300435
# 5              Swaddlers Diapers size 5            56.476667
# 6                        Diapers size 5            43.178750
# 7                                size 5            39.524815
# 8              Swaddlers Diapers size 2            55.880000
# 9                        Diapers size 2            41.437500
# 10                               size 2            22.969231
# 11             Swaddlers Diapers size 6            48.773333
# 12                       Diapers size 6            48.476000
# 13                               size 6            40.064348
# 14                               size 1            22.588696
# 15  countPampers Swaddlers Diapers size            35.360000
# 16        Swaddlers Diapers size 5 -128            52.135000
# 17                  Diapers size 5 -128            52.135000
# 18              Diapers size 5 -128 ct.            52.135000
# 19                          size 5 -128            52.135000
# 20               Swaddlers Diapers size            50.419444
# 21                         Diapers size            50.419444
# 22       Pampers Swaddlers Diapers size            50.419444
# 23   lb.)Pampers Swaddlers Diapers size            60.015455
# 24                               size 4            52.592000
# 25             Swaddlers Diapers size 5            56.476667
# 26                       Diapers size 5            56.476667
# 27                               size 5            56.476667
# 28             Swaddlers Diapers size 2            55.880000
# 29                       Diapers size 2            55.880000
# 30                               size 2            55.880000
# 31             Swaddlers Diapers size 6            48.773333
# 32                       Diapers size 6            48.773333
# 33                               size 6            48.773333
# 34                               size 1            27.980000
# 35  countPampers Swaddlers Diapers size            35.360000
# 36        Swaddlers Diapers size 5 -128            52.135000
# 37                  Diapers size 5 -128            52.135000
# 38              Diapers size 5 -128 ct.            52.135000
# 39                          size 5 -128            52.135000
#
#     Avg_Sold_Price_25  Avg_Sold_Price_75  Total_Sold  Ship_Cost
# 0             40.2000            62.1975        18.0        0.0
# 1             31.2300            59.9900        62.0        0.0
# 2             40.2000            62.1975        18.0        0.0
# 3             57.7550            62.4650        11.0        0.0
# 4             43.4700            60.6700        23.0        0.0
# 5             52.1350            62.7200         3.0        0.0
# 6             33.7100            60.8500         8.0        0.0
# 7             16.0000            54.8700        27.0        0.0
# 8             52.9350            58.8250         2.0        0.0
# 9             30.9975            52.9350         4.0        0.0
# 10            10.0000            31.5100        13.0        0.0
# 11            41.9900            59.6850         3.0        0.0
# 12            36.9500            59.1100         5.0        0.0
# 13            21.9950            58.9500        23.0        0.0
# 14            11.7500            32.4950        23.0        0.0
# 15            29.0000            39.9500         5.0        0.0
# 16            48.0625            56.2075         2.0        0.0
# 17            48.0625            56.2075         2.0        0.0
# 18            48.0625            56.2075         2.0        0.0
# 19            48.0625            56.2075         2.0        0.0
# 20            40.2000            62.1975        18.0        0.0
# 21            40.2000            62.1975        18.0        0.0
# 22            40.2000            62.1975        18.0        0.0
# 23            57.7550            62.4650        11.0        0.0
# 24            45.9900            58.4800         5.0        0.0
# 25            52.1350            62.7200         3.0        0.0
# 26            52.1350            62.7200         3.0        0.0
# 27            52.1350            62.7200         3.0        0.0
# 28            52.9350            58.8250         2.0        0.0
# 29            52.9350            58.8250         2.0        0.0
# 30            52.9350            58.8250         2.0        0.0
# 31            41.9900            59.6850         3.0        0.0
# 32            41.9900            59.6850         3.0        0.0
# 33            41.9900            59.6850         3.0        0.0
# 34            21.9950            34.4750         3.0        0.0
# 35            29.0000            39.9500         5.0        0.0
# 36            48.0625            56.2075         2.0        0.0
# 37            48.0625            56.2075         2.0        0.0
# 38            48.0625            56.2075         2.0        0.0
# 39            48.0625            56.2075         2.0        0.0

# %% [markdown]
# ### Little Snugglers

# %%
# Filter the DataFrame
testing_df = filtered_df[filtered_df['Listing'].str.contains('Little Snugglers')]
testing_df
# Out:
#                                                 Listing  Avg_Sold_Price  \
# 13    Huggies Little Snugglers Diapers Huge Pack - S...           34.70
# 17    Little Snugglers Baby Diapers Size Preemie 2 P...           21.40
# 19    Huggies Little Snugglers Diapers Giant Pack - ...           34.71
# 32    Huggies Little Snugglers Diapers - Size 4 - 14...           37.13
# 34    Huggies Little Snugglers Diapers Huge Pack - S...           34.76
# ...                                                 ...             ...
# 5632  Huggies Little Snugglers Baby Diaper for Newbo...           40.99
# 5634  Huggies Little Movers & Little Snugglers Diape...           59.95
# 5652  Huggies Baby Diapers Little Snugglers Up to 6l...           19.10
# 5670  Huggies Little Snugglers Diapers Size 1 96 Cou...           20.00
# 5699  Baby Diapers Size 1 198 Ct Huggies Little Snug...           53.32
#
#       Total_Sales  Total_Sold       Date  Shipping  \
# 13       12769.61       368.0 2024-03-19      0.00
# 17          64.20         3.0 2024-03-19      0.00
# 19        8538.63       246.0 2024-03-19      0.00
# 32        1448.14        39.0 2024-03-19      0.00
# 34        6917.98       199.0 2024-03-19      0.00
# ...           ...         ...        ...       ...
# 5632       491.88        12.0 2022-01-17      0.00
# 5634      1378.77        23.0 2022-01-16      0.00
# 5652        19.10         1.0 2022-01-13      0.00
# 5670        20.00         1.0 2022-01-08      1.65
# 5699        53.32         1.0 2022-01-03      0.00
#
#                                          Title_Keywords
# 13    [Huggies, Little, Diapers, Huge, Pack, Size, L...
# 17    [Little, Snugglers, Baby, Diapers, Size, Preem...
# 19    [Huggies, Little, Diapers, Giant, Pack, Size, ...
# 32             [Huggies, Little, Diapers, Size, Little]
# 34    [Huggies, Little, Diapers, Huge, Pack, Size, L...
# ...                                                 ...
# 5632  [Huggies, Little, Snugglers, Baby, Diaper, New...
# 5634  [Huggies, Little, Movers, Little, Diapers, Siz...
# 5652  [Huggies, Baby, Diapers, Little, Snugglers, Up...
# 5670  [Huggies, Little, Diapers, Size, Little, Diape...
# 5699  [Baby, Diapers, Size, Ct, Huggies, Little, Snu...
#
# [408 rows x 7 columns]

# %%
# Apply the function to the Titles column
phrases = testing_df['Listing'].apply(extract_phrases).sum()

# Count the occurrences of each phrase
phrase_counts = Counter(phrases)

# Find the most common phrases
most_common_phrases = phrase_counts.most_common()

# %%
most_common_phrases_df = pd.DataFrame(most_common_phrases, columns=['Name', 'Count'])
most_common_phrases_df.head(25)
# Out:
#                                      Name  Count
# 0                        Little Snugglers    784
# 1                            Diapers Size    480
# 2                            Baby Diapers    462
# 3                          Snugglers Baby    426
# 4                   Little Snugglers Baby    424
# 5                          Huggies Little    384
# 6                  Snugglers Baby Diapers    384
# 7           Little Snugglers Baby Diapers    382
# 8                       Baby Diapers Size    379
# 9                Huggies Little Snugglers    360
# 10            Snugglers Baby Diapers Size    348
# 11     Little Snugglers Baby Diapers Size    346
# 12          Huggies Little Snugglers Baby    194
# 13                                 Size 1    187
# 14               Little Snugglers Diapers    172
# 15                      Snugglers Diapers    172
# 16  Huggies Little Snugglers Baby Diapers    171
# 17                           Size Newborn    139
# 18                                 Size 2    131
# 19                         Diapers Size 1    124
# 20                   Diapers Size Newborn    113
# 21              Baby Diapers Size Newborn    106
# 22                         Diapers Size 2    103
# 23    Snugglers Baby Diapers Size Newborn     99
# 24                                 - Size     90

# %%
# Filter the column containing the word "size"
size_df = most_common_phrases_df[most_common_phrases_df['Name'].str.contains('Size')]

type_product = size_df.head(20)['Name'].tolist()

# %%
dict_sales = {'Phrase': [], 'Avg_Sold_Price_mean': [], 'Avg_Sold_Price_25': [], 'Avg_Sold_Price_75': [], 'Total_Sold': [], 'Ship_Cost': []}

# %%
for phrase in type_product:
    # Filter rows where 'vitamin' or 'Vitamin' is in the list
    temp_df = testing_df[testing_df['Listing'].apply(lambda x: phrase in x)]

    mean = temp_df.describe()['Avg_Sold_Price'].tolist()[1]

    percent_25 = temp_df.describe()['Avg_Sold_Price'].tolist()[4]

    percent_75 = temp_df.describe()['Avg_Sold_Price'].tolist()[6]

    count = temp_df.describe()['Total_Sold'].tolist()[0]

    ship = temp_df.describe()['Shipping'].tolist()[5]
    
    dict_sales['Phrase'].append(phrase)
    dict_sales['Avg_Sold_Price_mean'].append(mean)
    dict_sales['Avg_Sold_Price_25'].append(percent_25)
    dict_sales['Avg_Sold_Price_75'].append(percent_75)
    dict_sales['Total_Sold'].append(count)
    dict_sales['Ship_Cost'].append(ship)
    
pd.DataFrame.from_dict(dict_sales)
# Out:
#                                  Phrase  Avg_Sold_Price_mean  \
# 0                          Diapers Size            35.926360
# 1                     Baby Diapers Size            35.222864
# 2           Snugglers Baby Diapers Size            34.282047
# 3    Little Snugglers Baby Diapers Size            34.282047
# 4                                Size 1            31.618367
# 5                          Size Newborn            28.591507
# 6                                Size 2            42.032143
# 7                        Diapers Size 1            32.263182
# 8                  Diapers Size Newborn            27.840000
# 9             Baby Diapers Size Newborn            27.840000
# 10                       Diapers Size 2            43.498545
# 11  Snugglers Baby Diapers Size Newborn            26.158367
# 12                               - Size            32.070222
# 13                  Baby Diapers Size 1            32.287143
# 14        Snugglers Baby Diapers Size 1            32.265238
# 15                  Baby Diapers Size 2            41.241667
# 16        Snugglers Baby Diapers Size 2            40.155152
# 17                               Size 3            38.591333
# 18        Little Snugglers Diapers Size            40.968148
# 19               Snugglers Diapers Size            40.968148
#
#     Avg_Sold_Price_25  Avg_Sold_Price_75  Total_Sold  Ship_Cost
# 0             21.2000            48.9900       239.0        0.0
# 1             19.9700            47.9850       199.0        0.0
# 2             18.6000            45.0000       171.0        0.0
# 3             18.6000            45.0000       171.0        0.0
# 4             20.4950            39.9850        98.0        0.0
# 5             15.0000            37.5400        73.0        0.0
# 6             32.2475            51.7150        70.0        0.0
# 7             22.0325            39.9975        66.0        0.0
# 8             12.7425            38.2050        56.0        0.0
# 9             12.7425            38.2050        56.0        0.0
# 10            33.3800            55.6750        55.0        0.0
# 11            11.9700            35.0000        49.0        0.0
# 12            25.9900            36.9900        45.0        0.0
# 13            19.9500            40.8000        49.0        0.0
# 14            22.0325            40.6000        42.0        0.0
# 15            28.9925            49.7100        42.0        0.0
# 16            26.9900            52.2900        33.0        0.0
# 17            22.7250            45.0000        30.0        0.0
# 18            30.0000            54.0300        27.0        0.0
# 19            30.0000            54.0300        27.0        0.0

# %% [markdown]
# # Automation By Price

# %%
filtered_df= data_df.loc[data_df['Avg_Sold_Price'] > 20]


def extract_phrases(title):
    tokens = title.split()  # Tokenize the title
    phrases = []
    for i in range(len(tokens)):
        for j in range(i + 1, min(i + 6, len(tokens) + 1)):  # Generate combinations of 2 to 5 words
            phrase = ' '.join(tokens[i:j])
            if len(phrase.split()) >= 2 and len(phrase.split()) <= 5:  # Check if phrase length is between 2 and 5
                phrases.append(phrase)
    return phrases

# Apply the function to the Titles column
phrases = filtered_df['Listing'].apply(extract_phrases).sum()

# Count the occurrences of each phrase
phrase_counts = Counter(phrases)

# Find the most common phrases
most_common_phrases = phrase_counts.most_common()

most_common_phrases_df = pd.DataFrame(most_common_phrases, columns=['Name', 'Count'])

# Filter the DataFrame
testing_df = filtered_df[filtered_df['Listing'].str.contains('Baby Toys')]

# Apply the function to the Titles column
phrases = testing_df['Listing'].apply(extract_phrases).sum()

# Count the occurrences of each phrase
phrase_counts = Counter(phrases)

# Find the most common phrases
most_common_phrases = phrase_counts.most_common()


most_common_phrases_df = most_common_phrases_df[most_common_phrases_df['Name'].apply(lambda x: len(x.split()) > 3)]

type_product = most_common_phrases_df['Name'].head(15).tolist()

dict_sales = {'Phrase': [], 'Avg_Sold_Price_mean': [], 'Avg_Sold_Price_25': [], 'Avg_Sold_Price_75': [], 'Total_Sold': [], 'Ship_Cost': []}

for phrase in type_product:
    # Filter rows where 'vitamin' or 'Vitamin' is in the list
    temp_df = data_df[data_df['Listing'].apply(lambda x: phrase in x)]

    mean = temp_df.describe()['Avg_Sold_Price'].tolist()[1]

    percent_25 = temp_df.describe()['Avg_Sold_Price'].tolist()[4]

    percent_75 = temp_df.describe()['Avg_Sold_Price'].tolist()[6]

    count = temp_df.describe()['Total_Sold'].tolist()[0]

    ship = temp_df.describe()['Shipping'].tolist()[5]
    
    dict_sales['Phrase'].append(phrase)
    dict_sales['Avg_Sold_Price_mean'].append(mean)
    dict_sales['Avg_Sold_Price_25'].append(percent_25)
    dict_sales['Avg_Sold_Price_75'].append(percent_75)
    dict_sales['Total_Sold'].append(count)
    dict_sales['Ship_Cost'].append(ship)
    
pd.DataFrame.from_dict(dict_sales)
# Out:
#                         Phrase  Avg_Sold_Price_mean  Avg_Sold_Price_25  \
# 0               for 1 Year Old            26.276527            15.5750
# 1              Toys for 1 Year            25.474537            15.2650
# 2          Toys for 1 Year Old            25.781357            15.2900
# 3               6 to 12 Months            21.518037            13.5900
# 4                 Toys 6 to 12            22.755842            13.9900
# 5        Learn Coffee Mug Baby            29.417234            25.0000
# 6          Toys 6 to 12 Months            21.823684            13.4500
# 7              Wake Up & Learn            27.885000            24.5000
# 8               Baby Toys 6 to            23.051067            14.0525
# 9            Baby Toys 6 to 12            23.104375            13.9900
# 10              1 Year Old Boy            27.647533            16.3800
# 11     Coffee Mug Baby Stanley            28.236441            21.6250
# 12          for 1 Year Old Boy            29.314417            16.3200
# 13  Fisher-Price Laugh & Learn            24.719713            13.8700
# 14      Wake Up & Learn Coffee            27.112075            23.9800
#
#     Avg_Sold_Price_75  Total_Sold  Ship_Cost
# 0             33.6350       239.0        0.0
# 1             32.8050       227.0        0.0
# 2             32.9300       221.0        0.0
# 3             26.7150       219.0        0.0
# 4             29.4250       190.0        0.0
# 5             34.9900        94.0        0.0
# 6             28.0650       171.0        0.0
# 7             33.2825        96.0        0.0
# 8             29.8275       178.0        0.0
# 9             29.9075       176.0        0.0
# 10            35.0000       150.0        0.0
# 11            33.0850        59.0        0.0
# 12            39.3450       120.0        0.0
# 13            30.8175       174.0        0.0
# 14            33.4400        53.0        0.0
