# %%
import pandas as pd

# %%
data_df = pd.read_csv('women_top.csv')
data_df
# Out:
#      Unnamed: 0                                            Listing  \
# 0             0  , preview full size imageWomen Boho Floral Kim...
# 1             1  , preview full size imageNWT Sundance Catalog ...
# 2             2  , preview full size imageLands End Button Down...
# 3             3  , preview full size imageAnne Klein Jeans Wome...
# 4             4  , preview full size imageCharter Club Top Wome...
# ..          ...                                                ...
# 745          45  , preview full size imageOld Navy Woman 3/4 Fl...
# 746          46  , preview full size imageSleevey Wonders Women...
# 747          47  , preview full size imageNEW!! Buffalo Women's...
# 748          48  , preview full size imageCandace Cameron Bure ...
# 749          49  , preview full size imageSleevey Wonders Women...
#
#                              Actions     Avg Sold Price  \
# 0    EditSell SimilarExclude listing  $19.52Fixed price
# ...
